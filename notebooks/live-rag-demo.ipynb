# %% [markdown]
# # Rag ChatBot That Can Talk to Tables (.csv) files

# %%
data_path = "./assets-resources/superheroes.csv"

import pandas as pd

df = pd.read_csv(data_path)

# %%
df
# Out:
#       Superhero Name                             Superpower  Power Level  \
# 0    Captain Thunder                      Bolt Manipulation           90
# 1      Silver Falcon                     Flight and Agility           85
# 2      Mystic Shadow             Invisibility and Illusions           78
# 3       Blaze Runner                            Pyrokinesis           88
# 4       Electra-Wave                  Electric Manipulation           82
# 5    Crimson Cyclone                            Super Speed           91
# 6          Aqua Fury                           Hydrokinesis           80
# 7     Lunar Guardian                     Lunar Manipulation           77
# 8        Steel Titan          Super Strength and Durability           95
# 9         Nightblade               Night Vision and Stealth           84
# 10         Frostbite                       Ice Manipulation           87
# 11         Starburst                      Energy Projection           83
# 12        Sonic Dash                     Sound Manipulation           86
# 13        Nova Surge      Energy Absorption and Redirection           89
# 14         Shadowcat                          Intangibility           76
# 15        Neon Spark                     Light Manipulation           79
# 16     Phoenix Flame               Resurrection and Healing           94
# 17  Crystal Guardian                       Crystallokinesis           81
# 18       Earthshaker                             Geokinesis           92
# 19     Silver Seraph                            Telekinesis           85
# 20      Stormbringer                   Weather Manipulation           93
# 21     Scarlet Siren                           Mind Control           88
# 22       Rift Walker                     Dimensional Travel           90
# 23     Chrono-Wizard                      Time Manipulation           91
# 24     Blazing Comet                    Fireball Projection           82
# 25      Phantom Wisp                           Invisibility           75
# 26   Luminous Knight                          Luminokinesis           78
# 27     Gravity Shift                   Gravity Manipulation           89
# 28     Solar Empress                Solar Energy Absorption           87
# 29  Twilight Specter                    Shadow Manipulation           80
# 30     Thunderstrike                      Lightning Control           91
# 31     Nebula Weaver                        Reality Warping           96
# 32        Frostglide                     Cryo-Teleportation           85
# 33      Zenith Blaze                            Heat Vision           83
# 34    Astral Drifter                      Astral Projection           79
# 35      Blade Dancer              Swordsmanship and Agility           88
# 36     Azure Tempest                     Water Manipulation           82
# 37    Ghost Sentinel         Intangibility and Invisibility           76
# 38         Ember Fox           Pyrokinetic Fox Shapeshifter           89
# 39        Psy-Bender                              Telepathy           84
# 40  Celestial Sphinx                       Cosmic Awareness           93
# 41        Dragonfist      Dragon Summoning and Martial Arts           92
# 42       Solar Flare                Solar Energy Projection           85
# 43       Night Lotus                  Darkness Manipulation           78
# 44   Quantum Strider                   Quantum Manipulation           90
# 45          Ironclad  Invulnerability and Enhanced Strength           95
# 46    Shadow Stalker                        Shadow Shifting           81
# 47       Aqua Archer                 Water Arrow Projection           80
# 48     Crystal Gazer                   Crystal Ball Scrying           77
#
#                              Catchphrase
# 0           Feel the power of the storm!
# 1                 Soar high, fearlessly!
# 2           Disappear into the darkness!
# 3                Burn bright and fierce!
# 4            Unleash the electric waves!
# 5          Blazing fast and unstoppable!
# 6               Ride the waves of power!
# 7              Embrace the moon's might!
# 8        Indestructible force of nature!
# 9               Strike from the shadows!
# 10                     Chill your bones!
# 11                    Ignite the cosmos!
# 12            Hear the sound of victory!
# 13            Harness the energy within!
# 14         Phase through the impossible!
# 15                      Glow and dazzle!
# 16                  Rise from the ashes!
# 17               Shatter your illusions!
# 18   Feel the earth tremble beneath you!
# 19          Move objects with your mind!
# 20             Unleash the storm's fury!
# 21                     Obey my commands!
# 22                  Step between worlds!
# 23                Master of time's flow!
# 24           Burn brighter than a comet!
# 25    Disappear like a wisp in the wind!
# 26         Illuminate the darkest night!
# 27            Bend gravity to your will!
# 28         Harness the power of the sun!
# 29                   Dance with shadows!
# 30            Electrify the battlefield!
# 31          Shape the fabric of reality!
# 32       Freeze and glide through space!
# 33      Gaze into the flames of justice!
# 34                Roam the astral plane!
# 35              Dance with deadly grace!
# 36           Unleash the tempest's rage!
# 37                Haunt your nightmares!
# 38        Outfox your enemies with fire!
# 39         Read minds like an open book!
# 40  Unravel the secrets of the universe!
# 41            Unleash the dragon's fury!
# 42               Feel the burning light!
# 43                 Bloom in the shadows!
# 44             Walk the edge of reality!
# 45                Invincible and mighty!
# 46       Disappear and reappear at will!
# 47           Shoot through water's flow!
# 48            See what the future holds!

# %%
from langchain_community.document_loaders import CSVLoader

docs = CSVLoader(data_path).load_and_split()
docs
# Out:
# [Document(metadata={'source': './assets-resources/superheroes.csv', 'row': 0}, page_content='Superhero Name: Captain Thunder\nSuperpower: Bolt Manipulation\nPower Level: 90\nCatchphrase: Feel the power of the storm!'),
#  Document(metadata={'source': './assets-resources/superheroes.csv', 'row': 1}, page_content='Superhero Name: Silver Falcon\nSuperpower: Flight and Agility\nPower Level: 85\nCatchphrase: Soar high, fearlessly!'),
#  Document(metadata={'source': './assets-resources/superheroes.csv', 'row': 2}, page_content='Superhero Name: Mystic Shadow\nSuperpower: Invisibility and Illusions\nPower Level: 78\nCatchphrase: Disappear into the darkness!'),
#  Document(metadata={'source': './assets-resources/superheroes.csv', 'row': 3}, page_content='Superhero Name: Blaze Runner\nSuperpower: Pyrokinesis\nPower Level: 88\nCatchphrase: Burn bright and fierce!'),
#  Document(metadata={'source': './assets-resources/superheroes.csv', 'row': 4}, page_content='Superhero Name: Electra-Wave\nSuperpower: Electric Manipulation\nPower Level: 82\nCatchphrase: Unleash the electric waves!'),
#  Document(metadata={'source': './assets-resources/superheroes.csv', 'row': 5}, page_content='Superhero Name: Crimson Cyclone\nSuperpower: Super Speed\nPower Level: 91\nCatchphrase: Blazing fast and unstoppable!'),
#  Document(metadata={'source': './assets-resources/superheroes.csv', 'row': 6}, page_content='Superhero Name: Aqua Fury\nSuperpower: Hydrokinesis\nPower Level: 80\nCatchphrase: Ride the waves of power!'),
#  Document(metadata={'source': './assets-resources/superheroes.csv', 'row': 7}, page_content="Superhero Name: Lunar Guardian\nSuperpower: Lunar Manipulation\nPower Level: 77\nCatchphrase: Embrace the moon's might!"),
#  Document(metadata={'source': './assets-resources/superheroes.csv', 'row': 8}, page_content='Superhero Name: Steel Titan\nSuperpower: Super Strength and Durability\nPower Level: 95\nCatchphrase: Indestructible force of nature!'),
#  Document(metadata={'source': './assets-resources/superheroes.csv', 'row': 9}, page_content='Superhero Name: Nightblade\nSuperpower: Night Vision and Stealth\nPower Level: 84\nCatchphrase: Strike from the shadows!'),
#  Document(metadata={'source': './assets-resources/superheroes.csv', 'row': 10}, page_content='Superhero Name: Frostbite\nSuperpower: Ice Manipulation\nPower Level: 87\nCatchphrase: Chill your bones!'),
#  Document(metadata={'source': './assets-resources/superheroes.csv', 'row': 11}, page_content='Superhero Name: Starburst\nSuperpower: Energy Projection\nPower Level: 83\nCatchphrase: Ignite the cosmos!'),
#  Document(metadata={'source': './assets-resources/superheroes.csv', 'row': 12}, page_content='Superhero Name: Sonic Dash\nSuperpower: Sound Manipulation\nPower Level: 86\nCatchphrase: Hear the sound of victory!'),
#  Document(metadata={'source': './assets-resources/superheroes.csv', 'row':
'),
#  Document(metadata={'source': './assets-resources/superheroes.csv', 'row': 36}, page_content="Superhero Name: Azure Tempest\nSuperpower: Water Manipulation\nPower Level: 82\nCatchphrase: Unleash the tempest's rage!"),
#  Document(metadata={'source': './assets-resources/superheroes.csv', 'row': 37}, page_content='Superhero Name: Ghost Sentinel\nSuperpower: Intangibility and Invisibility\nPower Level: 76\nCatchphrase: Haunt your nightmares!'),
#  Document(metadata={'source': './assets-resources/superheroes.csv', 'row': 38}, page_content='Superhero Name: Ember Fox\nSuperpower: Pyrokinetic Fox Shapeshifter\nPower Level: 89\nCatchphrase: Outfox your enemies with fire!'),
#  Document(metadata={'source': './assets-resources/superheroes.csv', 'row': 39}, page_content='Superhero Name: Psy-Bender\nSuperpower: Telepathy\nPower Level: 84\nCatchphrase: Read minds like an open book!'),
#  Document(metadata={'source': './assets-resources/superheroes.csv', 'row': 40}, page_content='Superhero Name: Celestial Sphinx\nSuperpower: Cosmic Awareness\nPower Level: 93\nCatchphrase: Unravel the secrets of the universe!'),
#  Document(metadata={'source': './assets-resources/superheroes.csv', 'row': 41}, page_content="Superhero Name: Dragonfist\nSuperpower: Dragon Summoning and Martial Arts\nPower Level: 92\nCatchphrase: Unleash the dragon's fury!"),
#  Document(metadata={'source': './assets-resources/superheroes.csv', 'row': 42}, page_content='Superhero Name: Solar Flare\nSuperpower: Solar Energy Projection\nPower Level: 85\nCatchphrase: Feel the burning light!'),
#  Document(metadata={'source': './assets-resources/superheroes.csv', 'row': 43}, page_content='Superhero Name: Night Lotus\nSuperpower: Darkness Manipulation\nPower Level: 78\nCatchphrase: Bloom in the shadows!'),
#  Document(metadata={'source': './assets-resources/superheroes.csv', 'row': 44}, page_content='Superhero Name: Quantum Strider\nSuperpower: Quantum Manipulation\nPower Level: 90\nCatchphrase: Walk the edge of reality!'),
#  Document(metadata={'source': './assets-resources/superheroes.csv', 'row': 45}, page_content='Superhero Name: Ironclad\nSuperpower: Invulnerability and Enhanced Strength\nPower Level: 95\nCatchphrase: Invincible and mighty!'),
#  Document(metadata={'source': './assets-resources/superheroes.csv', 'row': 46}, page_content='Superhero Name: Shadow Stalker\nSuperpower: Shadow Shifting\nPower Level: 81\nCatchphrase: Disappear and reappear at will!'),
#  Document(metadata={'source': './assets-resources/superheroes.csv', 'row': 47}, page_content="Superhero Name: Aqua Archer\nSuperpower: Water Arrow Projection\nPower Level: 80\nCatchphrase: Shoot through water's flow!"),
#  Document(metadata={'source': './assets-resources/superheroes.csv', 'row': 48}, page_content='Superhero Name: Crystal Gazer\nSuperpower: Crystal Ball Scrying\nPower Level: 77\nCatchphrase: See what the future holds!')]

# %%
len(docs)
# Out:
# 49

# %%
from langchain_chroma.vectorstores import Chroma
from langchain_openai.embeddings import OpenAIEmbeddings

embeddings = OpenAIEmbeddings()
vector_store = Chroma.from_documents(
    documents=docs,
    embedding=embeddings,
    collection_name="superhero-collection",
    persist_directory="./superhero-db"
)

# %%
from langchain.tools import tool
from langchain_core import vectorstores
from langchain.agents import create_agent

@tool
def retrieve_table_context(query: str):
    """
    Retrieves information from vectorstore with data about superhero db (.csv).
    """
    retrieved_docs = vector_store.similarity_search(query, k=5)
    return retrieved_docs

tools = [retrieve_table_context]

superhero_checker_agent = create_agent(
    model="openai:gpt-5-mini",
    system_prompt="You have access to a tool to retrieve context from a .csv table about superheroes information.",
    tools=tools
)

# %%
df.head()
# Out:
#     Superhero Name                  Superpower  Power Level  \
# 0  Captain Thunder           Bolt Manipulation           90
# 1    Silver Falcon          Flight and Agility           85
# 2    Mystic Shadow  Invisibility and Illusions           78
# 3     Blaze Runner                 Pyrokinesis           88
# 4     Electra-Wave       Electric Manipulation           82
#
#                     Catchphrase
# 0  Feel the power of the storm!
# 1        Soar high, fearlessly!
# 2  Disappear into the darkness!
# 3       Burn bright and fierce!
# 4   Unleash the electric waves!

# %%
msg = "What is the superhero with the power of bolts?"
superhero_checker_agent.invoke(
    {"messages": [msg]}
)
# Out:
# {'messages': [HumanMessage(content='What is the superhero with the power of bolts?', additional_kwargs={}, response_metadata={}, id='cebcb133-4a35-4c8e-8499-afe6aa80d87b'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 89, 'prompt_tokens': 163, 'total_tokens': 252, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CnUB52zaSQbh2UatRJIwtTHnEy05R', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b2871-e3ad-7aa1-8773-7501cefd4f79-0', tool_calls=[{'name': 'retrieve_table_context', 'args': {'query': 'power bolts'}, 'id': 'call_eRMcFM6zohlRi81UJftBdOkS', 'type': 'tool_call'}], usage_metadata={'input_tokens': 163, 'output_tokens': 89, 'total_tokens': 252, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}}),
#   ToolMessage(content='[Document(id=\'6ea39882-8500-4a1d-ae23-9b852a8ee172\', metadata={\'row\': 0, \'source\': \'./assets-resources/superheroes.csv\'}, page_content=\'Superhero Name: Captain Thunder\\nSuperpower: Bolt Manipulation\\nPower Level: 90\\nCatchphrase: Feel the power of the storm!\'), Document(id=\'20c97012-4dbc-47d9-aeee-2fe7058a4a04\', metadata={\'row\': 30, \'source\': \'./assets-resources/superheroes.csv\'}, page_content=\'Superhero Name: Thunderstrike\\nSuperpower: Lightning Control\\nPower Level: 91\\nCatchphrase: Electrify the battlefield!\'), Document(id=\'f04aaf22-bd9e-4733-81b8-53111d63ed73\', metadata={\'row\': 20, \'source\': \'./assets-resources/superheroes.csv\'}, page_content="Superhero Name: Stormbringer\\nSuperpower: Weather Manipulation\\nPower Level: 93\\nCatchphrase: Unleash the storm\'s fury!"), Document(id=\'c1d1ebd7-5da6-4906-897d-bcc880a3d360\', metadata={\'row\': 27, \'source\': \'./assets-resources/superheroes.csv\'}, page_content=\'Superhero Name: Gravity Shift\\nSuperpower: Gravity Manipulation\\nPower Level: 89\\nCatchphrase: Bend gravity to your will!\'), Document(id=\'6cba2a6e-56f5-4a33-bd40-96c91aea8904\', metadata={\'source\': \'./assets-resources/superheroes.csv\', \'row\': 42}, page_content=\'Superhero Name: Solar Flare\\nSuperpower: Solar Energy Projection\\nPower Level: 85\\nCatchphrase: Feel the burning light!\')]', name='retrieve_table_context', id='abe1faee-7a03-4c81-a599-04d633d21baa', tool_call_id='call_eRMcFM6zohlRi81UJftBdOkS'),
#   AIMessage(content='The superhero is Captain Thunder — Superpower: Bolt Manipulation (Power Level: 90; Catchphrase: "Feel the power of the storm!").\n\nRelated heroes with lightning/weather powers: Thunderstrike (Lightning Control, Power Level 91) and Stormbringer (Weather Manipulation, Power Level 93).', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 264, 'prompt_tokens': 594, 'total_tokens': 858, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CnUB75ePKDHfkN45HqW9z5fQR8EbY', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b2871-ebd8-71f3-ba71-95cb7002c52f-0', usage_metadata={'input_tokens': 594, 'output_tokens': 264, 'total_tokens': 858, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}})]}
