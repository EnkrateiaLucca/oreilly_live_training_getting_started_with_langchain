# %%
import openai
import os
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())

# %%
# Out:
# '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'

# %%
from langchain.chat_models import ChatOpenAI

# %%
model = ChatOpenAI(model="gpt-3.5-turbo-1106", api_key=os.getenv("OPENAI_API_KEY"))

# %%
model.predict("Hi I am presenting a live-training about large language models!")
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 model.predict("Hi I am presenting a live-training about large language models!")
#
# File ~/miniconda3/envs/oreilly-langchain/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:668, in BaseChatModel.predict(self, text, stop, **kwargs)
#     666 else:
#     667     _stop = list(stop)
# --> 668 result = self([HumanMessage(content=text)], stop=_stop, **kwargs)
#     669 if isinstance(result.content, str):
#     670     return result.content
#
# File ~/miniconda3/envs/oreilly-langchain/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:632, in BaseChatModel.__call__(self, messages, stop, callbacks, **kwargs)
#     625 def __call__(
#     626     self,
#     627     messages: List[BaseMessage],
#    (...)
#     630     **kwargs: Any,
# ...
